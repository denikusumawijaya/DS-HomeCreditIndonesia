# %%
import pandas as pd
df = pd.read_csv("application_train.csv")

# %%
import numpy as np
from sklearn import preprocessing
X = np.array([df.AMT_INCOME_TOTAL, df.AMT_CREDIT])
X = np.transpose(X)
X.shape
# Out:
# (307511, 2)

# %%
y = np.array([df.TARGET])
y = np.transpose(y)
y.shape
# Out:
# (307511, 1)

# %%
import matplotlib.pyplot as plt
X = X[:,:2]
x_min, x_max = X[:,0].min()-1,X[:,0].max()+1
y_min, y_max = X[:,1].min()-1,X[:,1].max()+1
plt.scatter(X[:,0],X[:,1],c=y)
plt.xlabel('AMT_IMCOME_TOTAL')
plt.ylabel('AMT_CREDIT')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.3, random_state = 1)
print(f'X train : {X_train.shape}')
print(f'y train : {y_train.shape}')
print(f'X test : {X_test.shape}')
print(f'y test : {y_test.shape}')

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print(f'Accuracy: {acc}')
# Out:
# X train : (215257, 2)
# y train : (215257, 1)
# X test : (92254, 2)
# y test : (92254, 1)
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy: 0.9142476206993735

# %%
X_train = X
y_train = y

df_2 = pd.read_csv("application_test.csv")
X_test = np.array([df_2.AMT_INCOME_TOTAL, df_2.AMT_CREDIT])
X_test = np.transpose(X_test)

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

preds = model.predict(X_test)
preds
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# array([0, 0, 0, ..., 0, 0, 0])

# %%
x_min, x_max = X_test[:,0].min()-1,X_test[:,0].max()+1
y_min, y_max = X_test[:,1].min()-1,X_test[:,1].max()+1
plt.scatter(X_test[:,0],X_test[:,1],c=preds)
plt.xlabel('AMT_INCOME_TOTAL')
plt.ylabel('AMT_CREDIT')
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.grid(True)
plt.show()
